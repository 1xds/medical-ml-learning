# %% [markdown]
# # Module 17: SHAP Bootstrap
# ## SHAP Bootstrap Analysis
#
# ---
#
# ### 学习目标
#
# （参见本模块 README.md）
#
# ---

# %% [markdown]
# ## 0. 环境准备

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False

print('Environment ready.')

# %% [markdown]
# ## 1. 数据加载
#
# > TODO: 加载本模块所需数据集

# %%
# df = pd.read_csv('your_data.csv')
# df.head()

# %% [markdown]
# ## 2. 核心实践
#
# > TODO: 按照教程逐步实现本模块核心内容
# > 注意：自己重新敲代码，不要复制粘贴

# %%
# Your code here

# %% [markdown]
# ## 3. 可视化
#
# > 将运行结果保存到 images/ 目录

# %%
# plt.savefig('images/result.png', dpi=150, bbox_inches='tight')

# %% [markdown]
# ## 4. Reflection
#
# ### 本次实验发现
# - TODO: 记录你的发现
#
# ### 踩坑记录
# - TODO: 记录遇到的问题和解决方案
#
# ### 下一步
# - TODO: 下一步学习计划
